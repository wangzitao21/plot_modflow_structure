# %%
from plot_modflow_structure import plot_modflow_structure
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'


plot_modflow_structure(x_number=30, y_number=30, csv_dir='./csv_dir/')
